# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

colors = ["#89CFF0", "#FF69B4", "#FFD700", "#7B68EE", "#FF4500",
          "#9370DB", "#32CD32", "#8A2BE2", "#FF6347", "#20B2AA",
          "#FF69B4", "#00CED1", "#FF7F50", "#7FFF00", "#DA70D6"]

# %%
df = pd.read_csv("shopping_trends_updated.csv")
df.sample(5)
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 2506         2507   57   Male          Dress     Clothing
# 360           361   51   Male          Pants     Clothing
# 2168         2169   23   Male        Handbag  Accessories
# 1835         1836   65   Male          Scarf  Accessories
# 2240         2241   57   Male        Sandals     Footwear
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 2506                     82      New York   XL    Orange  Spring
# 360                      30  Rhode Island    M      Teal  Summer
# 2168                     74   Connecticut    M     Beige  Spring
# 1835                     75      Kentucky    M  Lavender    Fall
# 2240                     71    California    L     Green  Winter
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 2506            4.4                  No   Free Shipping               No
# 360             3.0                 Yes        Standard              Yes
# 2168            4.1                  No    Next Day Air               No
# 1835            3.2                  No  2-Day Shipping               No
# 2240            4.3                  No    Next Day Air               No
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 2506              No                  19          Venmo               Annually
# 360              Yes                  18     Debit Card            Fortnightly
# 2168              No                  32           Cash              Quarterly
# 1835              No                  45    Credit Card              Quarterly
# 2240              No                  18     Debit Card         Every 3 Months

# %%
categories = ['Male', 'Female']
values = df['Gender'].value_counts()

total = sum(values)

fig, ax = plt.subplots()
bars = ax.bar(categories, values)

for bar in bars:
    height = bar.get_height()
    percentage = (height / total) * 100
    ax.annotate('{:.1f}%'.format(percentage),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords='offset points',
                ha='center', va='bottom')

plt.show()

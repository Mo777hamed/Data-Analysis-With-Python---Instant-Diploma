# %%
import pandas as pd
import matplotlib.pyplot as plt

colors = ["#89CFF0", "#FF69B4", "#FFD700", "#7B68EE", "#FF4500",
          "#9370DB", "#32CD32", "#8A2BE2", "#FF6347", "#20B2AA",
          "#FF69B4", "#00CED1", "#FF7F50", "#7FFF00", "#DA70D6"]

# %%
df = pd.read_csv("shopping_trends_updated.csv")
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3881         3882   56  Female          Scarf  Accessories
# 986           987   54    Male          Scarf  Accessories
# 3208         3209   61  Female        Jewelry  Accessories
# 1816         1817   26    Male            Hat  Accessories
# 2732         2733   21  Female          Socks     Clothing
#
#       Purchase Amount (USD)     Location Size   Color  Season  Review Rating  \
# 3881                     25      Georgia    L  Silver  Spring            2.8
# 986                      96  Connecticut    S   Peach  Spring            4.5
# 3208                     30      Indiana    L  Indigo  Winter            3.3
# 1816                     79     Virginia    M  Purple  Summer            4.0
# 2732                     75     Delaware    L  Orange  Winter            4.2
#
#      Subscription Status   Shipping Type Discount Applied Promo Code Used  \
# ...

# %%
def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{:.1f}%\n({v:d})'.format(pct, v=val)
        return my_format

# %%
plt.figure(figsize=(20,6))

counts=df['Gender'].value_counts()
explode=(0,0.1)

counts.plot(kind='pie', colors=colors, explode=explode, autopct= autopct_format(counts))

plt.title('Males Vs Females')
plt.xlabel('Gender', weight='bold', color='#2F0F5D', fontsize=15, labelpad=20)
plt.ylabel('Count', weight='bold', color='#2F0F5D', fontsize=15, labelpad=20)
plt.legend(labels=counts.index, loc='best')
plt.show()
